# %% [markdown]
# # Matplotlib

# %% [markdown]
# #### A very quick overview

# %% [markdown]
# ## Let us visit the website first

# %% [markdown]
# > Resources: http://matplotlib.org/

# %%
from IPython.display import Image
Image("http://matplotlib.org/_static/logo2.png")

# %% [markdown]
# ## Installation

# %% [markdown]
# Depends on numpy package and therefore requires some C compilation, which will be handle automatically

# %% [markdown]
# open a shell and type:
#
# ```
# pip install matplotlib -U
# ```
#
# You may need root permission.

# %% [markdown]
# ## Using matplotlib

# %% [markdown]
# #### 1. In the notebook, type this command to import all functionalities and include images in the notebook automatically:

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### 2. In a script or shell:

# %%
import pylab

# %% [markdown]
# #### 3. In ipython, starts ipython as follows::

# %% [markdown]
# ```
# ipython --pylab
# ```

# %% [markdown]
# ### Notes for fine tuning

# %%
# somehow confusing but pylab package is part of matplotlib
import matplotlib 
matplotlib.rcParams['figure.figsize'] = (10,8)

# %% [markdown]
# ## Some data to play with

# %% [markdown]
# ### A dataframe with compound information
# (dataframe from pandas)

# %%
# pip install bioservices should work
from bioservices import ChEMBL

# %%
chembl = ChEMBL()

# %%
res = chembl.get_compounds_by_chemblId(['CHEMBL%s' % i for i in range(0,1000)])

# %%
# some results are not found and tagged as 404 integer
# let us remove them
res = [x for x in res if x != 404]

# %%
res[0]
# Out:
# {u'compound': {u'acdLogd': 7.67,
#   u'acdLogp': 7.67,
#   u'alogp': 3.63,
#   u'chemblId': u'CHEMBL1',
#   u'knownDrug': u'No',
#   u'medChemFriendly': u'Yes',
#   u'molecularFormula': u'C32H32O8',
#   u'molecularWeight': 544.59,
#   u'numRo5Violations': 1,
#   u'passesRuleOfThree': u'No',
#   u'rotatableBonds': 2,
#   u'smiles': u'COc1ccc2[C@@H]3[C@H](COc2c1)C(C)(C)OC4=C3C(=O)C(=O)C5=C4OC(C)(C)[C@@H]6COc7cc(OC)ccc7[C@H]56',
#   u'stdInChiKey': u'GHBOEFUAGSHXPO-XZOTUCIWSA-N'}}

# %%
# select compound to make things easier
res = [x['compound'] for x in res]

# %% [markdown]
# ### Pandas uses matplotlib

# %% [markdown]
# Pandas like many other Python packages uses matplotlib behind the scene

# %%
import pandas as pd
df = pd.DataFrame(res)
df.fillna(0, inplace=True)
df.plot(x='alogp', y='molecularWeight', marker='o', kind='scatter')

# %% [markdown]
# BUT we are going to learn about matplotlib. Let us reproduce that picture first

# %% [markdown]
# ## The **plot** function

# %% [markdown]
# #### what we'll see in this section:
# - **plot** function
# - marker, linestyle, color parameters

# %% [markdown]
# Let us use the dataframe to extract 2 variables.
# If you do not have Pandas, just type
#
# ```python
# X = [x['alogp'] for x in res]
# Y = [x['molecularWeight'] for x in res]
# ```

# %%
X = df['alogp']
Y = df['molecularWeight']

# %% [markdown]
# ### 2 variables case

# %%
plot(X, Y)

# %%
# Let us make it nicer by providing a marker:
plot(X, Y, marker='o')

# %%
# let us also remove the lines
plot(X, Y, marker='o', linestyle='')

# %%
# an alias to the marker and linestyle is to use a third positional
# argument. Here b means blue color, o means circle marker and no 
# third letter is provided for the style
plot(X, Y, 'bo')

# %% [markdown]
# look into the doc to figure out
# - the color (e.g., k for black, r for red,...)
# - the marker (e.g., o for circles, x for crosses, s for square)
# - the line style (e.g., -- for lines, - for dashed lines)

# %%
plot(X, Y, color='red', marker='s', linewidth=0)

# %% [markdown]
# ### 1 variable case and the hold function

# %%
# You can provide just 1 variable as an input to the plot function:
plot(X, marker='o')

# %%
plot(X, 'ro')
# hold is True by default
plot(Y/20, 'go')

# %%
plot(X, 'ro')
hold(False)
plot(Y/20, 'go')
hold(True)

# %% [markdown]
# ## xlabel and ylabel

# %% [markdown]
# #### what we'll see in this section:
# - xlabel and ylabel functions

# %%
# note that color may be provided as hexadecimal values
plot(X, Y, 'o', markersize=8, color='#ffaa11')
xlabel('alogp')
ylabel('molecularWeight')

# %%
# just an alias for later.
def set_labels():
    xlabel('alogp')
    ylabel('molecularWeight')

# %% [markdown]
# ## grid

# %% [markdown]
# #### what we'll see in this section
# - markersize parameter
# - fontsize parameter
# - alpha parameter
# - grid function

# %%
plot(X, Y, 'o', markersize=8)
xlabel('alogp')
ylabel('molecularWeight')
grid()

# %%
# a bit more tuning on the grid and fontsize 
plot(X, Y, 'o', markersize=8)
xlabel('alogp', fontsize=20)
ylabel('molecularWeight',fontsize=20, color='red')
grid(color='r', linewidth=2, linestyle='--', alpha=0.5)

# %% [markdown]
# ## loglog, semilog

# %%
loglog(X, Y, 'or', alpha=0.5, markersize=8)

# %%
semilogy(X, Y, 'y*', markersize=20, alpha=.5)
grid() # works also with log scale

# %% [markdown]
# ## histogram

# %%
# from the Pandas dataframe, we can plot an histogram
df.hist('alogp')
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x9208750>]], dtype=object)

# %% [markdown]
# How does that work in pure matplotlib ?

# %%
hist(X)
grid()
title('alogp')

# %%
x, y, z = hist(X, bins=30, normed=True)
grid()
title('alogp')

# %%
x, y, z = hist(Y, bins=30, normed=True, alpha=0.5)
x, y, z = hist(Y+200, bins=30, normed=True, alpha=0.5)

# %%
x, y, z = hist([Y, Y+200]
               , bins=30, normed=True)

# %% [markdown]
# ## plot a counter (dictionary)

# %% [markdown]
# Maybe you already know the values of the histogram (e.g., from a counter)

# %%
from bioservices import UniProt
u = UniProt()
fasta = u.get_fasta_sequence('P43403')

# %%
from collections import Counter
counter = Counter(fasta)

# %%
counter
# Out:
# Counter({u'L': 62, u'A': 54, u'E': 46, u'G': 42, u'K': 42, u'P': 42, u'S': 38, u'R': 37, u'D': 31, u'Y': 31, u'V': 29, u'I': 24, u'Q': 23, u'T': 23, u'M': 21, u'F': 18, u'C': 17, u'H': 16, u'N': 14, u'W': 9})

# %% [markdown]
# How to represent this data ?

# %% [markdown]
# - values of the counter dictionary will be bars (y)
# - x values should be from 1 to the number of keys
# - labels of the bar on the x-axisd should be replaced by the letter

# %% [markdown]
# ## bar and xticks

# %%
# Let us get the values sorted alphabetically 
values = []
for k in sorted(counter.keys()):
    values.append(counter[k])
# list comprehension: 
# values = [counter[k] for k in sorted(counter.keys())]
values
# Out:
# [54, 17, 31, 46, 18, 42, 16, 24, 42, 62, 21, 14, 42, 23, 37, 38, 23, 29, 9, 31]

# %%
#X and Y mus be provided
bar(values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-5c97bce3e389> in <module>()
#       1 #X and Y mus be provided
# ----> 2 bar(values)
#
# TypeError: bar() takes at least 2 arguments (1 given)

# %%
# we need values for X, let us use a range
xvalues = range(0, len(values))

# %%
bar(xvalues, values)

# %%
# xticks() return current position and labels of the ticks
bar(xvalues, values)
xt = xticks()
xt
# Out:
# (array([  0.,   5.,  10.,  15.,  20.]), <a list of 5 Text xticklabel objects>)

# %%
# ticks can be redefined for each bar
bar(xvalues, values)
_ = xticks([x+0.5 for x in xvalues], sorted(counter.keys()), color='red')

# %% [markdown]
# ## boxplot

# %%
_ = boxplot([X, Y])

# %%
xticks([1,2], ['alogp', 'molecularWeight'])
# Out:
# ([<matplotlib.axis.XTick at 0x14078d10>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %% [markdown]
# hum, here we called xticks and it created a new figure ? As you may already noticed, different cells create different figures

# %%
_ = boxplot([X, Y])
_ = xticks([1,2], ['alogp', 'molecularWeight'], rotation=90)

# %% [markdown]
# ## scatter

# %% [markdown]
# - scatter
# - colorbar

# %%
scatter(X, Y, s=50) # note that it is not markersize but s parameter
grid()

# %%
# let us create a third dimension (random value) for the size
# should be same length as X
Z = 300*abs(random.random(len(X)))

# %%
# color could be distance to the center
C = sqrt( ((X-X.mean())/X.mean())**2 + ((Y - Y.mean())/Y.mean())**2 )

# %%
scatter((X-X.mean())/X.mean(), (Y-Y.mean())/Y.mean(), s=Z, alpha=0.5, c=C)
grid()
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x18462a28>

# %% [markdown]
# ## color map

# %%
scatter(X, Y, s=Z, alpha=0.5, c=C, cmap='jet')
grid()
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x185e7ef0>

# %%
import colormap

# %%
len(colormap.colormap_names)
# Out:
# 149

# %%
colormap.test_cmap(colormap.colormap_names[2])
colormap.colormap_names[2]
# Out:
# 'Blues'

# %%
scatter(X, Y, s=Z, c=C, cmap='Blues', linewidths=0)
grid()
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1a4a7248>

# %% [markdown]
# ## hist2d

# %%
out = hist2d(X, Y, bins=20, cmap='copper_r')
set_labels()
colorbar()
# let us plot the data as well
plot(X,Y, 'kx', alpha=0.3)

# %% [markdown]
# ## subplot

# %% [markdown]
# See matplotlib examples and also the GridSpec function

# %% [markdown]
# ## legend

# %%
#cumulative = False
#normed = True
#alpha = 0.5
#bins = 20

x, y, z = hist(Y , bins=20, color='blue', normed=True, cumulative=False,
               alpha=0.5, 
               label=r'$\alpha$')

x, y, z = hist(Y+400, bins=20, normed=True, color='red', cumulative=False,
               alpha=0.5, label=r'$\alpha + 400$')

legend(fontsize=25, ncol=2)
grid()
# note that without the r letter, you must escape \ sign
xlabel(r'$\mathcal{X}$', fontsize=16)  
ylabel('$\int_0^\infty X dX$  or $ \mathcal{F}(x) $ or whater Latex equation', 
       fontsize=16)

# %% [markdown]
# ## Figure and axes

# %% [markdown]
# Behaviour in ipython and python shell are different

# %% [markdown]
# So far we always used one figure and one axes. What are they ?
# How to create a figure, an axes?

# %% [markdown]
# - Technically a **figure** is a window that pops up.
# - A figure can contain **axes**
# - So far, each time we've called a matplotlib plotting function (e.g., plot, hist, scatter), a figure was automatically created and then an axes was automatically created.
# - axes and figure can be tuned. For instance, the axes that contains
#   an histogram can be completed with xlabels, title and so on.

# %%
fig = figure(figsize=(10,6), facecolor='gray', frameon=True)
ax1 = fig.add_axes([0.1,0.2,0.35,0.4])
ax1.scatter(X, Y)
# or 
ax2 = fig.add_axes([0.5,0.5,0.35,0.4])
_ = ax2.hist(X)
# axes can be manipulated afterwards
ax1.set_xlabel('example')

# %%
from biokit.viz import scatter_hist

# %%
_ = scatter_hist(X, Y)

# %% [markdown]
# ## subplots

# %%
subplot(2,1,1)
_ = hist(X)
subplot(2,1,2)
_ = hist(Y)

# %% [markdown]
# ## Patches: Example from matplotlib

# %%
from matplotlib.patches import Ellipse
NUM = 250

ells = [Ellipse(xy=rand(2)*10, width=rand(), height=rand(), angle=rand()*360)
        for i in range(NUM)]

fig = figure()
ax = fig.add_subplot(111, aspect='equal')
for e in ells:
    ax.add_artist(e)
    e.set_clip_box(ax.bbox)
    e.set_alpha(rand())
    e.set_facecolor(rand(3))

ax.set_xlim(0, 10)
ax.set_ylim(0, 10)
# Out:
# (0, 10)

# %% [markdown]
# ## Conclusions

# %% [markdown]
# We've seen
#
# - plot, hist, scatter, hist2d, semilogx, se;milogy, loglog , colorbar, plotting functions
# - axes and figure notions
# - colormap
# - xticks, xlabels, ylabels, title
# - patches (Ellipse)
# - tunable parameters: alpha, fontsize, marker, markersize
#
# There are many more functions. Of interest:
#
# - meshgrid, griddata
# - 3D plots
# - polar
# - quiver

# %% [markdown]
# ## Help ?

# %% [markdown]
# - matplotlib web page and its gallery of examples
# - stackoverflow
# - pynxton mailing list
